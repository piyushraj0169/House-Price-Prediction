# %% [markdown]
# # House Price Prediction - Analysis
#
# This notebook performs exploratory data analysis and model training for the House Price Prediction project.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.data_loader import load_dataset, display_dataset_info
from src.preprocessing import clean_dataset, separate_features_target
from src.utils import save_eda_plots, generate_statistical_summary
from src.train import train_models

# %%
data_path = PROJECT_ROOT / 'data' / 'housing.csv'
data = load_dataset(data_path)
data.head()

# %%
display_dataset_info(data)

# %%
cleaned_data = clean_dataset(data)
generate_statistical_summary(cleaned_data)

# %%
save_eda_plots(cleaned_data, PROJECT_ROOT / 'output' / 'plots')

# %%
features, target = separate_features_target(cleaned_data)
features.head(), target.head()

# %%
best_model, comparison_table = train_models(data_path)
comparison_table
